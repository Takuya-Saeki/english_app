# %% [markdown]
# - pタグをとったら本文の抽出は十分できていた
# - pタグ単位で、英訳して、単語リストを作って表示すれば良さそう
# - pタグ単位でtextを取得して、textのリストとして本文を持つ
# - 改行文字などの変な記号を取り除いたほうがいいかも

# %%
import requests
from bs4 import BeautifulSoup

# %%
# urlのpタグからテキストを抽出
def scrape_text_from_url(url:str)->[str]:
    response = requests.get(url)
    html = response.content

    # BeautifulSoupオブジェクトを作成
    soup = BeautifulSoup(html, 'html.parser')

    # noscriptタグをすべて削除
    for noscript in soup.find_all('noscript'):
        noscript.decompose()

    # 本文が含まれると思われるタグを抽出（例：'p' タグ）
    article_text = ''
    for paragraph in soup.find_all('p'):
        article_text += paragraph.get_text()
    # テキスト整形用の文字列を除去する
    clean_text = article_text.replace('\u3000', '')
    clean_text = clean_text.replace('\t', '')

    # 改行文字ごとにテキストを分割する
    splited_text = [line for line in clean_text.split('\n') if line.strip() != '']
    return splited_text


# URLにアクセスしてHTMLを取得
url_list = ['https://media.alpen-group.jp/media/detail/baseball_230316_01.html',"https://news.yahoo.co.jp/articles/5eefc9b1ad0f838b45c527587819a13262d10085","https://www.oricon.co.jp/news/2304930/","https://www.jiji.com/jc/article?k=2023112400917&g=soc"]
url = url_list[3]
print(scrape_text_from_url(url))
# Out:
# ['時事ドットコムニュース社会「メディアと価値観」巡りシンポスマートニュースが開催2023年11月24日19時27分調査結果を説明するスマートニュースメディア研究所の山脇岳志所長＝２４日午後、東京都渋谷区', 'ニュース配信アプリを手掛けるスマートニュース（東京）は２４日、人々の政治的価値観の傾向やＳＮＳなどメディアとの関わりについてのシンポジウムを東京都内で開いた。', '記事使用料、引き上げに慎重大手ＩＴ、報道機関に説明強化―ニュースポータルサイト', 'シンポジウムにはメディア論の専門家ら７人が参加。スマート社のシンクタンクのメディア研究所が今年３月に行ったアンケート調査を基に、メディアへの信頼や政治的価値観の分布状況などのテーマで研究報告が行われた。', '山脇岳志メディア研究所長らは日米での政治的分断について報告した。新聞やテレビへの信頼度は、米国では民主、共和党支持者間で大きな差があるが、日本では保守、リベラル層も７割程度が信頼しほとんど差がなかったとした。', 'メディアへの接触状況を分析した法政大の大森翔子専任講師は、若年層の６～７割が「新聞を読まない」と回答したと指摘。ＬＩＮＥ（ライン）などＳＮＳへの接触率は他の世代と比べて高いが、ニュースへの関心が低い傾向にあったという。', '同研究所は今後２年ごとに調査を実施し傾向を分析するとしている。', '関連記事こんな記事も社会用語社会笹子事故１１年、犠牲者悼む遺族「悲しみ変わらない」―山梨米オスプレイ２機、奄美空港到着不明者捜索、鹿児島県が使用届受理北海道でオーロラ観測赤いカーテン、肉眼でも今年に入り面識か渥美容疑者、交際に発展―１８歳女性遺体遺棄・警視庁「ふたに食事」「床にわざと水」岡崎署の不適切行為父親、何度も入院要望識者「勾留必要なかった」―岡崎署勾留死「日本社会の安全最優先」米国防総省、オスプレイ事故でどこでも発電「東京を未来都市に」小池知事がＣＯＰ２８出席大麻グミ成分、２日から禁止「ＨＨＣＨ」所持や使用規制―厚労省コンビニ従業員を誤認逮捕実際は窃盗被害なし―兵庫県警「化石燃料、段階的廃止を」ＣＯＰ２８で首脳級会合開幕―国連総長石炭火力、新規建設終了へ脱炭素・経済の両立重要―岸田首相・ＣＯＰ２８ソナー・潜水士、捜索続く米軍オスプレイ墜落７人不明―屋久島沖勾留死、岡崎署９人書類送検業過致死・
# ...

# %%
response = requests.get(url)
html = response.content

# BeautifulSoupオブジェクトを作成
soup = BeautifulSoup(html, 'html.parser')

# 本文が含まれると思われるタグを抽出（例：'p' タグ）
article_text = []
for paragraph in soup.find_all('p'):
    article_text.append(paragraph.get_text())
print(article_text)
# Out:
# ['時事ドットコムニュース', '社会', '「メディアと価値観」巡りシンポ\u3000スマートニュースが開催', '2023年11月24日19時27分', '調査結果を説明するスマートニュースメディア研究所の山脇岳志所長＝２４日午後、東京都渋谷区', '\n\t\u3000ニュース配信アプリを手掛けるスマートニュース（東京）は２４日、人々の政治的価値観の傾向やＳＮＳなどメディアとの関わりについてのシンポジウムを東京都内で開いた。\n', '記事使用料、引き上げに慎重\u3000大手ＩＴ、報道機関に説明強化―ニュースポータルサイト', '\n\t\u3000シンポジウムにはメディア論の専門家ら７人が参加。スマート社のシンクタンクのメディア研究所が今年３月に行ったアンケート調査を基に、メディアへの信頼や政治的価値観の分布状況などのテーマで研究報告が行われた。\n\t\u3000山脇岳志メディア研究所長らは日米での政治的分断について報告した。新聞やテレビへの信頼度は、米国では民主、共和党支持者間で大きな差があるが、日本では保守、リベラル層も７割程度が信頼しほとんど差がなかったとした。\n\t\u3000メディアへの接触状況を分析した法政大の大森翔子専任講師は、若年層の６～７割が「新聞を読まない」と回答したと指摘。ＬＩＮＥ（ライン）などＳＮＳへの接触率は他の世代と比べて高いが、ニュースへの関心が低い傾向にあったという。\n\t\u3000同研究所は今後２年ごとに調査を実施し傾向を分析するとしている。\n\t', '関連記事', 'こんな記事も', '社会用語', '社会', '笹子事故１１年、犠牲者悼む\u3000遺族「悲しみ変わらない」―山梨', '米オスプレイ２機、奄美空港到着\u3000不明者捜索、鹿児島県が使用届受理', '北海道でオーロラ観測\u3000赤いカーテン、肉眼でも', '今年に入り面識か\u3000渥美容疑者、交際に発展―１８歳女性遺体遺棄・警視庁', '「ふたに食事」「床にわざと水」\u3000岡崎署の不適切行為', '父親、何度も入院要望\u3000識者「勾留必要なかった」―岡崎署勾留死', '「日本社会の安全最優先」\u3000米国防総省、オスプレイ事故で', 'どこでも発電「東京を未来都市に」\u3000小池知事がＣＯＰ２８出席', '大
# ...

# %%
def split_text_ignore_empty_lines(text):
    # 改行で分割し、空でない行だけをリストに含める
    return [line for line in text.split('\n') if line.strip() != '']

# 例えばこのようなテキストを使用
text = "これはサンプルのテキストです。\nこれは次の行です。\n\nこれは空行の後の行です。"

# 関数を使ってテキストを分割
lines = split_text_ignore_empty_lines(text)

print(lines)
# Out:
# ['これはサンプルのテキストです。', 'これは次の行です。', 'これは空行の後の行です。']
