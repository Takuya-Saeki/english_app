# %%
# 中学生の英単語は以下から取得 https://www.eigo-duke.com/tango/chu.html#
# 共通テストレベルの単語は以下から取得 https://www.eigo-duke.com/tango/common.html
# 京大の英単語は以下から取得 https://www.eigo-duke.com/tango/kyoto.html#
# 東大レベルの英単語は以下から取得 https://www.eigo-duke.com/tango/tokyo.html#
# 英検2級レベルの英単語は以下から取得 https://www.eigo-duke.com/tango/eiken2.html#
# 英検準1級レベルの英単語リストは以下から取得 https://www.eigo-duke.com/tango/eikenjun1.html

# 高校受験レベル、共通テストレベル、2次試験レベルの単語リストを作成する

from bs4 import BeautifulSoup
from lxml import html
import re
import csv


def make_word_list(html_name):
    # HTMLファイルを開く
    with open(html_name, "r", encoding="utf-8") as file:
        # ファイルの内容を読み込む
        html_content = file.read()

    # BeautifulSoupを使用してHTMLを解析する
    soup = BeautifulSoup(html_content, "html.parser")

    # lxmlのhtmlパーサーを使用してHTMLを解析
    tree = html.fromstring(html_content)

    # 指定されたXPathにマッチする要素を取得
    # element = tree.xpath('/html/body/div[3]/div[2]/font/div[2]/table/tbody/tr[2]/td[3]/div')
    element = tree.xpath("/html/body")

    # '|'で分割して各セグメントを処理
    words = re.findall(r"\|([a-zA-Z]+)", element[0].text_content())
    return words


# for文で、それぞれのhtmlからword_listを作成し、連結させる
def words_list_to_csv(files_list, csv_name):
    words_list = []
    # 各htmlから単語リストを作成
    for i in range(len(files_list)):
        words_list.extend(make_word_list(files_list[i]))
    #単語のダブりをなくす
    words_list = list(set(words_list))
    print("{}単語のリストをcsvファイルで保存します".format(len(words_list)))
    
    # csvファイルで保存
    with open(csv_name, "w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        for word in words_list:
            writer.writerow([word])

# %%
# 高校受験レベル、共通テストレベル、2次試験レベルの単語リストに使用するhtmlのリストを作る
word_list_j_high_school = ["./html_folder/j_high_school.html"]
word_list_center_test = [
    "./html_folder/j_high_school.html",
    "./html_folder/center_test.html",
]
word_list_2zi_test = [
    "./html_folder/j_high_school.html",
    "./html_folder/center_test.html",
    "./html_folder/kyodai.html",
    "./html_folder/todai.html",
    "./html_folder/eiken_2.html",
    "./html_folder/eiken_sub1.html",
]
# 英熟語のリストを作る
idiom_list_j_high_school = [
    "./html_folder/idiom_j_high_school.html",
    "./html_folder/idiom_high_school_1.html",
    ]
idiom_list_center_test = ["./html_folder/idiom_center_test.html"]

idiom_list_2zi_test = ["./html_folder/idiom_soukei.html"]

# csvファイルの名前
csv_names = [
    "./csv_folder/word_list_j_high_school.csv",
    "./csv_folder/word_list_center_test.csv",
    "./csv_folder/word_list_2zi_test.csv",
    "./csv_folder/idiom_list_j_high_school.csv",
    "./csv_folder/idiom_list_center_test.csv",
    "./csv_folder/idiom_list_2zi_test.csv",
]

# レベルごとの単語帳のcsvを生成
# 高校受験の単語リスト
words_list_to_csv(word_list_j_high_school, csv_names[0])
# 共通テストの単語リスト
words_list_to_csv(word_list_center_test, csv_names[1])
# 2次試験の単語リスト
words_list_to_csv(word_list_2zi_test, csv_names[2])
# 高校受験の英熟語リスト
words_list_to_csv(idiom_list_j_high_school, csv_names[3])
# 共通テストの英熟語リスト
words_list_to_csv(idiom_list_center_test, csv_names[4])
# 2次試験の英熟語リスト
words_list_to_csv(idiom_list_2zi_test, csv_names[5])
# Out:
# 1395単語のリストをcsvファイルで保存します
# 2767単語のリストをcsvファイルで保存します
# 5617単語のリストをcsvファイルで保存します
# 146単語のリストをcsvファイルで保存します
# 261単語のリストをcsvファイルで保存します
# 464単語のリストをcsvファイルで保存します

# %% [markdown]
# 熟語用の関数も作らないといけない
#
# make_word_listの最後の正規表現のとこでバグってる

# %%
make_word_list("./html_folder/idiom_soukei.html")
# Out:
# ['rule',
#  'discourage',
#  'give',
#  'track',
#  'wash',
#  'air',
#  'pin',
#  'try',
#  'hold',
#  'fall',
#  'miss',
#  'drag',
#  'to',
#  'defend',
#  'life',
#  'after',
#  'for',
#  'deal',
#  'in',
#  'in',
#  'identify',
#  'pass',
#  'in',
#  'in',
#  'in',
#  'tuition',
#  'specialize',
#  'feed',
#  'send',
#  'rely',
#  'bring',
#  'in',
#  'in',
#  'run',
#  'blend',
#  'brush',
#  'cut',
#  'feed',
#  'go',
#  'knock',
#  'pass',
#  'pile',
#  'pull',
#  'bank',
#  'build',
#  'cover',
#  'dish',
#  'fit',
#  'pass',
#  'pass',
#  'press',
#  'pull',
#  'rub',
#  'stand',
#  'put',
#  'back',
#  'fall',
#  'pile',
#  'shake',
#  'see',
#  'win',
#  'tell',
#  'round',
#  'level',
#  'ease',
#  'bring',
#  'force',
#  'stick',
#  'slip',
#  'talk',
#  'grow',
#  'skim',
#  'branch',
#  'tip',
#  'scratch',
#  'hold',
#  'pass',
#  'blast',
#  'turn',
#  'pack',
#  'feel',
#  'stir',
#  'count',
#  'shut',
#  'lock',
#  'get',
#  'come',
#  'keep',
#  'stand',
#  'fall',
#  'cut',
#  'fire',
#  'stick',
#  'step',
#  'play',
#  'act',
#  'fix',
#  'throw',
#  'clean',
#  'grow',
#  'give',
#  'lift',
#  'come',
#  'hold',
#  'roll',
#  'stay',
#  'set',
#  'smooth',
#  'burn',
#  'cross',
#  'make',
#  'eat',
#  'run',
#  'crack',
#  'spring',
#  'fall',
#  'even',
#  'pull',
#  'pick',
#  'carry',
#  'be',
#  'give',
#  'bounce',
#  'stand',
#  'wrap',
#  'fall',
#  'trip',
#  'sit',
#  'play',
#  'head',
#  'set',
#  'take',
#  'bring',
#  'put',
#  'look',
#  'add',
#  'fall',
#  'get',
#  'hang',
#  'settle',
#  'back',
#  'drop',
#  'jump',
#  'face',
#  'play',
#  'read',
#  'hand',
#  'speak',
#  'weigh',
#  'bring',
#  'lay',
#  'break',
#  'stick',
#  'split',
#  'drive',
#  'talk',
#  'give',
#  'take',
#  'tie',
#  'set',
#  'let',
#  'pick',
#  'critical',
#  'place',
#  'contribute',
#  'along',
#  'low',
#  'subject',
#  'stop',
#  'in',
#  'give',
#  'in',
#  'law',
#  'go',
#  'biased',
#  'water',
#  'provide',
#  'look',
#  'regardless',
#  'take',
#  'make',
#  'to',
#  'experiment',
#  'keep',
#  'get',
#  'work',
#  'with',
#  'saving',
#  'what',
#  'hang',
#  'come',
#  'keep',
#  'catch',
#  'mother',
#  'role',
#  'invest',
#  'sign',
#  'across',
#  'in',
#  'what',
#  'despite',
#  'not',
#  'be',
#  'hang',
#  'cut',
#  'put',
#  'rebel',
#  'in',
#  'come',
#  'stay',
#  'get',
#  'put',
#  'finish',
#  'under',
#  'health',
#  'light',
#  'make',
#  'on',
#  'prevent',
#  'trade',
#  'down',
#  'go',
#  'register',
#  'on',
#  'by',
#  'lose',
#  'in',
#  'real',
#  'conform',
#  'believe',
#  'fall',
#  'hold',
#  'catch',
#  'pay',
#  'aim',
#  'clean',
#  'in',
#  'out',
#  'expose',
#  'look',
#  'to',
#  'put',
#  'in',
#  'application',
#  'bring',
#  'at',
#  'fill',
#  'at',
#  'a',
#  'combine',
#  'show',
#  'allow',
#  'play',
#  'limit',
#  'take',
#  'narrow',
#  'keep',
#  'confess',
#  'side',
#  'make',
#  'medical',
#  'all',
#  'at',
#  'stop',
#  'annual',
#  'keep',
#  'classify',
#  'in',
#  'drop',
#  'donate',
#  'in',
#  'come',
#  'close',
#  'sum',
#  'tune',
#  'call',
#  'show',
#  'sit',
#  'sink',
#  'make',
#  'wear',
#  'count',
#  'go',
#  'sell',
#  'do',
#  'take',
#  'put',
#  'on',
#  'distance',
#  'fit',
#  'stand',
#  'come',
#  'fight',
#  'miltary',
#  'civil',
#  'be',
#  'sort',
#  'push',
#  'push',
#  'wisdom',
#  'paid',
#  'end',
#  'in',
#  'be',
#  'associate',
#  'benefit',
#  'up',
#  'speaking',
#  'in',
#  'as',
#  'as',
#  'split',
#  'compare',
#  'threaten',
#  'to',
#  'in',
#  'fit',
#  'fall',
#  'on',
#  'match',
#  'obstacle',
#  'blood',
#  'just',
#  'hit',
#  'let',
#  'sales',
#  'no',
#  'out',
#  'help',
#  'distract',
#  'stick',
#  'advise',
#  'be',
#  'bank',
#  'replace',
#  'due',
#  'have',
#  'parking',
#  'grant',
#  'dual',
#  'integrate',
#  'attribute',
#  'conflict',
#  'replace',
#  'toxic',
#  'place',
#  'transmit',
#  'as',
#  'crash',
#  'replace',
#  'categorize',
#  'vice',
#  'be',
#  'town',
#  'public',
#  'natural',
#  'in',
#  'file',
#  'in',
#  'let',
#  'buckle',
#  'come',
#  'chip',
#  'slip',
#  'nod',
#  'cross',
#  'gear',
#  'leave',
#  'lock',
#  'kick',
#  'drop',
#  'get',
#  'send',
#  'grow',
#  'walk',
#  'point',
#  'head',
#  'back',
#  'come',
#  'hang',
#  'die',
#  'kick',
#  'get',
#  'live',
#  'best',
#  'pull',
#  'frankly',
#  'inside',
#  'burst',
#  'go',
#  'on',
#  'hand',
#  'break',
#  'pass',
#  'turn',
#  'mess',
#  'talk',
#  'as',
#  'up',
#  'believe',
#  'in',
#  'call',
#  'at',
#  'back',
#  'pull',
#  'deal',
#  'in',
#  'from',
#  'for',
#  'as',
#  'bring',
#  'fall',
#  'bound',
#  'out',
#  'under',
#  'in',
#  'on',
#  'at',
#  'around',
#  'tear',
#  'step',
#  'put',
#  'go',
#  'tear',
#  'around',
#  'come',
#  'take',
#  'hand',
#  'leave',
#  'insist',
#  'come',
#  'refrain',
#  'keep',
#  'gaze',
#  'stare',
#  'put',
#  'by',
#  'pull',
#  'before',
#  'first',
#  'make',
#  'for',
#  'in',
#  'owing',
#  'when',
#  'look',
#  'be',
#  'vote',
#  'cut',
#  'lean',
#  'in',
#  'no',
#  'come',
#  'compete',
#  'die',
#  'make',
#  'tend',
#  'so',
#  'submit',
#  'as',
#  'adjust',
#  'congratulate',
#  'be',
#  'take',
#  'be',
#  'to',
#  'be',
#  'without',
#  'be',
#  'in',
#  'be',
#  'as',
#  'free',
#  'improve',
#  'be',
#  'derive',
#  'get',
#  'scold',
#  'a',
#  'as',
#  'as',
#  'fix',
#  'think',
#  'in',
#  'be',
#  'take',
#  'up',
#  'attend',
#  'be',
#  'provided',
#  'come',
#  'interfere',
#  'hold',
#  'commit',
#  'at',
#  'way',
#  'forget',
#  'for',
#  'go',
#  'buy',
#  'pretend',
#  'quite',
#  'now',
#  'in',
#  'either',
#  'convict',
#  'catch',
#  'at',
#  'surrender',
#  'split',
#  'elaborate',
#  'bear',
#  'by',
#  'draw',
#  'learn',
#  'hardly',
#  'in',
#  'take',
#  'fall',
#  'spell',
#  'in',
#  'be',
#  'confide',
#  'consider',
#  'add',
#  'at',
#  'be',
#  'ever',
#  'none',
#  'down',
#  'in',
#  'associate',
#  'mother',
#  'wipe',
#  'to',
#  'screw',
#  'assure',
#  'top',
#  'prohibit',
#  'hesitate',
#  'sleep',
#  'check',
#  'on',
#  'hang',
#  'crop',
#  'be',
#  'sit',
#  'entrust',
#  'build',
#  'touch',
#  'close',
#  'fade',
#  'tens',
#  'cash',
#  'good',
#  'be',
#  'black',
#  'convince',
#  'bear',
#  'at',
#  'as',
#  'oddly',
#  'be',
#  'crank',
#  'be',
#  'in',
#  'in',
#  'loosen',
#  'beware',
#  'take',
#  'as',
#  'once',
#  'end',
#  'in',
#  'illustrate',
#  'starve',
#  'interfere',
#  'on',
#  'bet',
#  'concentrate',
#  'engage',
#  'at',
#  'free',
#  'by',
#  'be',
#  'hang',
#  'operate',
#  'be',
#  'ask',
#  'put',
#  'might',
#  'be',
#  'be',
#  'at',
#  'on',
#  'ascribe',
#  'hold',
#  'originate',
#  'be',
#  'watch',
#  'catch',
#  'classify',
#  'inquire',
#  'compare',
#  'irrespective',
#  'can',
#  'at',
#  'live',
#  'watch',
#  'one',
#  'from',
#  'take',
#  'for',
#  'close',
#  'break',
#  'contend',
#  'on',
#  'be',
#  'kick',
#  'strictly',
#  'cough',
#  'follow',
#  'abstain',
#  'conform',
#  'a',
#  'at',
#  'wash',
#  'get',
#  'catch',
#  'none',
#  'nothing',
#  'tie',
#  'ring',
#  'out',
#  'go',
#  'carry',
#  'lay',
#  'draw',
#  'take',
#  'fence',
#  'touch',
#  'write',
#  'buy',
#  'at',
#  'fall',
#  'give',
#  'make',
#  'stand',
#  'in',
#  'bail',
#  'tell',
#  'at',
#  'go',
#  'in',
#  'set',
#  'in',
#  'set',
#  'glare',
#  'kill',
#  'bump',
#  'rub',
#  'lean',
#  'stay',
#  'in',
#  'on',
#  'be',
#  'take',
#  'up',
#  'ease',
#  'lie',
#  'make',
#  'take',
#  'off',
#  'be',
#  'out',
#  'hook',
#  'notify',
#  'glance',
#  'go',
#  'in',
#  'have',
#  'speak',
#  'come',
#  'be',
#  'map',
#  'hide',
#  'in',
#  'stick',
#  'clear',
#  'beef',
#  'no',
#  'high',
#  'stamp',
#  'be',
#  'drink',
#  'under',
#  'in',
#  'in',
#  'to',
#  'crash',
#  'bottom',
#  'set',
#  'run',
#  'look',
#  'chew',
#  'with',
#  'kick',
#  'pop',
#  'be',
#  'dream',
#  'be',
#  'down',
#  'go',
#  'to',
#  'in',
#  'be',
#  'keep',
#  'entrust',
#  'on',
#  'break',
#  'be',
#  'be',
#  'spit',
#  'hole',
#  'drag',
#  'hand',
#  'out',
#  'think',
#  'level',
#  'roll',
#  'in',
#  'not',
#  'become',
#  'out',
#  'pull',
#  'point',
#  'tell',
#  'true',
#  'in',
#  'in',
#  'be',
#  'head',
#  'expand',
#  'pull',
#  'take',
#  'pull',
#  'put',
#  'have',
#  'write',
#  'ship',
#  'at',
#  'consent',
#  'crack',
#  'hinge',
#  'hit',
#  'turn',
#  'hear',
#  'worlds',
#  'let',
#  'for',
#  'be',
#  'pull',
#  'up',
#  'on',
#  'beyond',
#  'on',
#  'first',
#  'slip',
#  'all',
#  'inquire',
#  'stop',
#  'back',
#  'for',
#  'in',
#  'roll',
#  'in',
#  'burst',
#  'do',
#  'loud',
#  'praise',
#  'at',
#  'pick',
#  'sneak',
#  'bite',
#  'drink',
#  'at',
#  'in',
#  'in',
#  'the',
#  'draw',
#  'serve',
#  'under',
#  'take',
#  'be',
#  'walk',
#  'in',
#  'at',
#  'struggle',
#  'live',
#  'quarrel',
#  'under',
#  'go',
#  'gain',
#  'alive',
#  'give',
#  'just',
#  'wash',
#  'build',
#  'draw',
#  'to',
#  'on',
#  'in',
#  'hard',
#  'eat',
#  'yet',
#  'by',
#  'rule',
#  'make',
#  'want',
#  'edge',
#  'come',
#  'rise',
#  'jack',
#  'mingle',
#  'to',
#  'beyond',
#  'be',
#  'talk',
#  'in',
#  'right',
#  'root',
#  'in',
#  'trifle',
#  'be',
#  'be',
#  'admire',
#  'cheat',
#  'pay',
#  'get',
#  'conjure',
#  'out',
#  'least',
#  'iron',
#  'bow',
#  'bear',
#  'issue',
#  'be',
#  'be',
#  'from',
#  'in',
#  'bear',
#  'slip',
#  'abound',
#  'exert',
#  'equate',
#  'wrestle',
#  'be',
#  'in',
#  'inflict',
#  'to',
#  'have',
#  'zero',
#  'all',
#  'in',
#  'rest',
#  'complain',
#  'tear',
#  'snap',
#  'under',
#  'halfway',
#  'fall',
#  'trot',
#  'from',
#  'shed',
#  'pass',
#  'all',
#  'take',
#  'not',
#  'bowl',
#  'far',
#  'lie',
#  'take',
#  'put',
#  'be',
#  'break',
#  'cast',
#  'go',
#  'in',
#  'round',
#  'in',
#  'stick',
#  'think',
#  'take',
#  'drink',
#  'behind',
#  'put',
#  'do',
#  'make',
#  'be',
#  'head',
#  'bargain',
#  'make',
#  'branch',
#  'carry',
#  'sticking',
#  'swallow',
#  'the',
#  'in',
#  'strip',
#  'blow',
#  'an',
#  'hail',
#  'in',
#  'sleep',
#  'dos',
#  'no',
#  'ups',
#  'barge',
#  'call',
#  'word',
#  'catch',
#  'buy',
#  'set',
#  'in',
#  'bestow',
#  'ring',
#  'buck',
#  'to',
#  'phase',
#  'for',
#  'turn',
#  'out',
#  'odds',
#  'set',
#  'pertain',
#  'shelf',
#  'stumbling',
#  'pore',
#  'direct',
#  'pick',
#  'day',
#  'pan',
#  'and',
#  'up',
#  'shell',
#  'by',
#  'all',
#  'boil',
#  'be',
#  'sleep',
#  'back',
#  'capitalize',
#  'keep',
#  'succumb',
#  'with',
#  'down',
#  'without',
#  'hip',
#  'infringe',
#  'tide',
#  'pick',
#  'pay',
#  'lay',
#  'to',
#  'rank',
#  'ill',
#  'give',
#  'wear',
#  'in',
#  'run',
#  'in',
#  'water',
#  'fall',
#  'ball',
#  'at',
#  'have',
#  'steal',
#  'poke',
#  'reproach',
#  'in',
#  'land',
#  'buy',
#  'avail',
#  'gun',
#  'and',
#  'speak',
#  'wind',
#  'boil',
#  'ten',
#  'at',
#  'vouch',
#  'carve',
#  'in',
#  'rise',
#  'go',
#  'spring',
#  'fish',
#  'be',
#  'get',
#  'take',
#  ...]

# %%
# HTMLファイルを開く
with open("./html_folder/idiom_soukei.html", "r", encoding="utf-8") as file:
    # ファイルの内容を読み込む
    html_content = file.read()

# BeautifulSoupを使用してHTMLを解析する
soup = BeautifulSoup(html_content, "html.parser")

# lxmlのhtmlパーサーを使用してHTMLを解析
tree = html.fromstring(html_content)

# 指定されたXPathにマッチする要素を取得
# element = tree.xpath('/html/body/div[3]/div[2]/font/div[2]/table/tbody/tr[2]/td[3]/div')
element = tree.xpath("/html/body")
print(element[0].text_content())
# Out:
# No音英語日本語☑1|rule outを除外する，締め出す2|discourage A from BAがBするのをやめさせる3|give offを放つ，放出する4|track downの跡を辿る5|wash awayを洗い流す6|air outが乾く，乾燥する7|pin downをピンで留める，押さえつける8|try outを試す9|hold offを寄せ付けない，引き離す10|fall forに夢中になる，騙される11|miss out機会を逃す，見落とす12|drag on長引く，延々と続く13|to begin with最初に，最初から14|defend A against BBからAを守る15|life expectancy余命，寿命16|after all結局，最後は17|for instance例えば18|deal withを扱う，論じる19|in contrast対照的に20|in response toに応じて，に反応して21|identify A as BAがBだと分かる，認識する22|pass on通り過ぎる，を伝える23|in place ofの代わりに24|in shortつまり、要するに25|in other words言い換えれば，他の言葉で言うと26|tuition fee授業料27|specialize inを専門にする，に特化する28|feed onにエサをやる29|send inに送る30|rely onに頼る，を当てにする31|bring aboutを引き起こす，発生させる32|in exchange引き換えに，交換として33|in spite ofにも関わらず34|run down流れ落ちる，荒廃する35|blend in溶け合う，調和する36|brush offをすげなく断る，無視する37|cut downを減らす，削減する38|feed offから取って食べる，情報を得る39|go under失敗する，破産する40|knock downを取り壊す，打ち倒す41|pass forとして通る，通過する42|pile inどっと中に入る43|pull over車を止める44|bank onを当てにする，頼る45|build up増大する，築き上げる46|cover forを覆う，代理となる47|dish out盛り付ける，配膳する48|fit intoに溶け込む，調和する49|pass off次第に消える，うまくやる50|pass overを無視する，通り越す51|press forをせがむ，要求する52|pull throughを乗り越える53|rub in刷り込む，繰り返し言う54|stand overを監督する，延期する55|put forthを進める，出す56|back off後退する，後ろに下がる57|fall under支配下に入る，分類される58|pile upを積み上げる59|shake up大きく変える，再編する60|see throughを見抜く，見通す61|win overに勝つ，勝利する62|tell on言いつける，告げ口する63|round up寄せ集める，切り上げる64|level off平らにする65|ease intoにゆっくりと入る66|bring outを引き出す，引き起こす67|force downを無理やり飲み込む68|stick up forを支持する，を弁護する69|slip byそっと通り過ぎる70|talk down to見下して話す71|grow intoに発展する72|skim over流し読みする，ざっと読む73|branch off分岐する，枝を広げる74|tip overひっくり返る，転覆する75|scratch out(線を引いて)消す76|hold out持ちこたえる，我慢する77|pass out気絶する、出ていく78|blast off発射される79|turn downを断る，拒む80|pack upを荷造りする81|feel forを感じる，同情する82|stir upをかき混ぜる，刺激する83|count onに頼る，を当てにする84|shut outを締め出す85|lock inを閉じ込める86|get away withを避ける，からやり過ごす87|come down to結局，になる，に帰する88|keep up onの最新状況を把握する89|stand up toに抵抗する，耐える90|fall away弱まる，落ちる91|cut in切り込む，干渉する92|fire up点火する，起動する93|stick around居残る，うろうろする94|step down降りる，身を引く95|play upを重視する，強調する96|act onに従って行動する，演じる97|fix upを修理する，決定する98|throw offを投げ捨てる99|clean outを一掃する100|grow on成長する，大きくなる101|give away無償で配る，暴露する102|lift off離陸する103|come beforeの前に現れる104|hold overを持ち越す105|roll upを巻き上げる106|stay offから離れる，距離を取る107|set aside横に置く，取っておく108|smooth over丸く収める，穏便に済ます109|burn outを焼き尽くす110|cross out線を引いて消す111|make overを作り替える112|eat up食べつくす，使い果たす113|run againstにぶつかる，偶然出会う114|crack up大破する，くじける115|spring up突然現れる，跳ね上がる116|fall through失敗に終わる，駄目になる117|even out平らになる，安定する118|pull in到着する，片側に寄る119|pick throughを探る，選りすぐる120|carry throughやり通す，成し遂げる121|be tidied upきちんと片づけた，整えた122|give in降伏する，屈する123|bounce back持ち直す，跳ね返す124|stand down身を引く，引退する125|wrap up纏める，終了する126|fall off減少する127|trip upを躓かせる128|sit in座り込む129|play out最後まで演じる，遊ぶ130|head out出発する，去る131|set offを引き起こす132|take upを取り上げる133|bring offを成し遂げる134|put in取り付ける135|look down onを見下す136|add up to結局，になる137|fall back onに頼る138|get on withとうまくやっていく139|hang aroundうろつく，徘徊する140|settle upを支払う，清算する141|back down手を引く142|drop back後退する143|jump atに飛びつく144|face off対決する，向き合う145|play downを軽く扱う146|read offを読み上げる，すらすら読む147|hand offを渡す148|speak forを代弁する，弁護する149|weigh onの重荷になる，負担になる150|bring onを引き起こす151|lay offを解雇する，クビにする152|break downを壊す，解体する153|stick withに固執する，堅持する154|split upを分ける，分割する155|drive offを追い払う156|talk upを大袈裟にほめる157|give overを任せる158|take onを雇う，引き受ける159|tie upを縛り上げる160|set in始まる，起こる161|let upやめる，弱まる162|pick overを吟味して選ぶ163|critical ofを批判する164|place limitation onに制限を加える165|contribute toに貢献する166|along withに沿って167|low frequency低周波168|subject toの支配下にある，によると169|stop A from doing BAがBすることを止める170|in hope ofを期待して171|give rise toを生じさせる，を産む172|in search ofを探して，探索して173|law enforcement法の執行174|go againstに反して，に逆らって175|biased towardに対する偏見176|water vapor水蒸気177|provide A with BAにBを供給する178|look toを頼りにする179|regardless ofにも関わらず180|take A away from BBからAを取る181|make ends meet収支を合わせる，つじつまを合わせる182|to the point適切な，要領を得た183|experiment withを試す，実験する184|keep up withに遅れず付いていく185|get byどうにか切り抜ける186|work out体を鍛える，うまく行く187|with allにも関わらず，全力でも188|saving account普通預金189|what ifもし ...

# %%
# '|'で分割して各セグメントを処理
words = re.findall(r"\|([a-zA-Z]+)", element[0].text_content())
print(words)
# Out:
# ['rule', 'discourage', 'give', 'track', 'wash', 'air', 'pin', 'try', 'hold', 'fall', 'miss', 'drag', 'to', 'defend', 'life', 'after', 'for', 'deal', 'in', 'in', 'identify', 'pass', 'in', 'in', 'in', 'tuition', 'specialize', 'feed', 'send', 'rely', 'bring', 'in', 'in', 'run', 'blend', 'brush', 'cut', 'feed', 'go', 'knock', 'pass', 'pile', 'pull', 'bank', 'build', 'cover', 'dish', 'fit', 'pass', 'pass', 'press', 'pull', 'rub', 'stand', 'put', 'back', 'fall', 'pile', 'shake', 'see', 'win', 'tell', 'round', 'level', 'ease', 'bring', 'force', 'stick', 'slip', 'talk', 'grow', 'skim', 'branch', 'tip', 'scratch', 'hold', 'pass', 'blast', 'turn', 'pack', 'feel', 'stir', 'count', 'shut', 'lock', 'get', 'come', 'keep', 'stand', 'fall', 'cut', 'fire', 'stick', 'step', 'play', 'act', 'fix', 'throw', 'clean', 'grow', 'give', 'lift', 'come', 'hold', 'roll', 'stay', 'set', 'smooth', 'burn', 'cross', 'make', 'eat', 'run', 'crack', 'spring', 'fall', 'even', 'pull', 'pick', 'carry', 'be', 'give', 'bounce', 'stand', 'wrap', 'fall', 'trip', 'sit', 'play', 'head', 'set', 'take', 'bring', 'put', 'look', 'add', 'fall', 'get', 'hang', 'settle', 'back', 'drop', 'jump', 'face', 'play', 'read', 'hand', 'speak', 'weigh', 'bring', 'lay', 'break', 'stick', 'split', 'drive', 'talk', 'give', 'take', 'tie', 'set', 'let', 'pick', 'critical', 'place', 'contribute', 'along', 'low', 'subject', 'stop', 'in', 'give', 'in', 'law', 'go', 'biased', 'water', 'provide', 'look', 'regardless', 'take', 'make', 'to', 'experiment', 'keep', 'get', 'work', 'with', 'saving', 'what', 'hang', 'come', 'keep', 'catch', 'mother', 'role', 'invest', 'sign', 'across', 'in', 'what', 'despite', 'not', 'be', 'hang', 'cut', 'put', 'rebel', 'in', 'come', 'stay', 'get', 'put', 'finish', 'under', 'health', 'light', 'make', 'on', 'prevent', 'trade', 'down', 'go', 'register', 'on', 'by', 'lose', 'in', 'real', 'conform', 'believe', 'fall', 'hold', 'catch', 'pay', 'aim', 'clean', 'in', 'out', 'expose', 'look', 'to', 'put', 'in', 'application', 'bring', 'at', 'fill', 'at', 'a', 'combine', 'show', 'allow', 'play', 'limit', 'take', 'narrow', 'keep', 'confess', 'side', 'make', 'medical', 'all', 'at', 'stop', 'annual', 'keep', 'classify', 'in', 'drop', 'donate', 'in', 'come', 'close', 'sum', 'tune', 'call', 'show', 'sit', 'sink', 'make', 'wear', 'count', 'go', 'sell', 'do', 'take', 'put', 'on', 'distance', 'fit', 'stand', 'come', 'fight', 'miltary', 'civil', 'be', 'sort', 'push', 'push', 'wisdom', 'paid', 'end', 'in', 'be', 'associate', 'benefit', 'up', 'speaking', 'in', 'as', 'as', 'split', 'compare', 'threaten', 'to', 'in', 'fit', 'fall', 'on', 'match', 'obstacle', 'blood', 'just', 'hit', 'let', 'sales', 'no', 'out', 'help', 'distract', 'stick', 'advise', 'be', 'bank', 'replace', 'due', 'have', 'parking', 'grant', 'dual', 'integrate', 'attribute', 'conflict', 'replace', 'toxic', 'place', 'transmit', 'as', 'crash', 'replace', 'categorize', 'vice', 'be', 'town', 'public', 'natural', 'in', 'file', 'in', 'let', 'buckle', 'come', 'chip', 'slip', 'nod', 'cross', 'gear', 'leave', 'lock', 'kick', 'drop', 'get', 'send', 'grow', 'walk', 'point', 'head', 'back', 'come', 'hang', 'die', 'kick', 'get', 'live', 'best', 'pull', 'frankly', 'inside', 'burst', 'go', 'on', 'hand', 'break', 'pass', 'turn', 'mess', 'talk', 'as', 'up', 'believe', 'in', 'call', 'at', 'back', 'pull', 'deal', 'in', 'from', 'for', 'as', 'bring', 'fall', 'bound', 'out', 'under', 'in', 'on', 'at', 'around', 'tear', 'step', 'put', 'go', 'tear', 'around', 'come', 'take', 'hand', 'leave', 'insist', 'come', 'refrain', 'keep', 'gaze', 'stare', 'put', 'by', 'pull', 'before', 'first', 'make', 'for', 'in', 'owing', 'when', 'look', 'be', 'vote', 'cut', 'lean', 'in', 'no', 'come', 'compete', 'die', 'make', 'tend', 'so', 'submit', 'as', 'adjust', 'congratulate', 'be', 'take', 'be', 'to', 'be', 'without', 'be', 'in', 'be', 'as', 'free', 'improve', 'be', 'derive', 'get', 'scold', 'a', 'as', 'as', 'fix', 'think', 'in', 'be', 'take', 'up', 'attend', 'be', 'pro ...

# %%
# 高校受験レベル、共通テストレベル、2次試験レベルの単語リストに使用するhtmlのリストを作る
word_list_j_high_school = [
    "./html_folder/j_high_school_1.html",
    "./html_folder/j_high_school_2.html",
    "./html_folder/j_high_school_3.html",
    "./html_folder/j_high_school_all.html",
    "./html_folder/eiken_3.html",
]
word_list_center_test = [

    "./html_folder/center_test.html",
]
word_list_center_test.append(word_list_j_high_school)
word_list_2zi_test = [
    "./html_folder/kyodai.html",
    "./html_folder/todai.html",
    "./html_folder/eiken_2.html",
    "./html_folder/eiken_sub1.html",
]
word_list_2zi_test.append(word_list_center_test)

# %%
word_list_j_high_school.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/saekitakuya/Documents/GitHub/english_app/word_list/debug_make_word_list.ipynb セル 8 line 1
# ----> <a href='vscode-notebook-cell:/Users/saekitakuya/Documents/GitHub/english_app/word_list/debug_make_word_list.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> word_list_j_high_school.lower()
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
word_list_2zi_test
# Out:
# ['./html_folder/kyodai.html',
#  './html_folder/todai.html',
#  './html_folder/eiken_2.html',
#  './html_folder/eiken_sub1.html',
#  ['./html_folder/center_test.html',
#   ['./html_folder/j_high_school_1.html',
#    './html_folder/j_high_school_2.html',
#    './html_folder/j_high_school_3.html',
#    './html_folder/j_high_school_all.html',
#    './html_folder/eiken_3.html']]]
